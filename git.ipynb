# %%
from os.path import join
from google.colab import drive

ROOT='/content/drive'
drive.mount(ROOT)
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
# !ls /content/drive/'My Drive'/'datasciencestudy'
# Out:
# '2-1. 훈련 데이터와 테스트 데이터'
# '2-2. 데이터 전처리'
#  chpter3_회귀알고리즘과모델규제-1.ipynb
#  chpter3_회귀알고리즘과모델규제-2.ipynb
#  chpter3_회귀알고리즘과모델규제3.ipynb
#  git.ipynb

# %%
PROJ = "/drive/'My Drive'/'datasciencestudy"
PROJ_PATH=join(ROOT,PROJ)

# %%
import os
import sys

sys.path.insert(0, PROJ_PATH)

# %%
# %cd /content/drive/'My Drive'/'datasciencestudy'
# Out:
# /content/drive/My Drive/datasciencestudy

# %%
# !pwd
# Out:
# /content/drive/My Drive/datasciencestudy

# %%
# !git clone https://github.com/6058ah/DataScienceStudy.git
# Out:
# Cloning into 'DataScienceStudy'...
# ...

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/datasciencestudy/.git/

# %%
# !git config --global user.email "6058ah@naver.com"
# !git config --global user.name "[설정할 username]"
